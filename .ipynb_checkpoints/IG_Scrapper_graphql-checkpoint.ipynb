# %% [markdown]
# # Instagram Scrapper with GraphQL

# %% [markdown]
# Greetings, in this notebook i'm going to implement an IG Scrapper in order to extract information needed from a specific page in Instagram Social Media. The reason I decided to implement it myself is tackling the problem first hands so I would have a clear vision and understanding in explanation of my thesis, also in order to make progress in my thesis and data-wise, I need to save my data and features in a specific way so my machine learning algorithm would work flawlessly.
#
# This Scrapper was implemented with the help of Igscrapper source code from realsirjoe Github account you can check it here: [realsirjoe Github Account](https://github.com/realsirjoe)

# %% [markdown]
# ### this section is for necessary imports:

# %%
import pandas as pd
import numpy as np
import time
import requests
import json
from openpyxl import load_workbook
import http.cookiejar
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException 
import re
pd.set_option('display.max_columns', None)

# %% [markdown]
# The main reason for implementing this scrapper is to retrieve comments from posts which I have their address in my dataset. Instagram use this format as its posts:
#
#
# https://instagram.com/p/some_chars_as_post_link/
#
#
# I had stored my posts link in a field in my dataset which you can see below some examples of it:

# %%
df_posts = pd.read_excel('Data/MSc_Thesis_Dataset.xlsx')
df_posts.head()
# Out:
#    index    post_link                                            caption  \
# 0      1  BhIjjhfFy7k  .\n@BeKhatereMan\n.\nاگر شما هم نگران عزیزانتا...
# 1      2  BhIjhiuF0Ip  .\n@BeKhatereMan\n.\nاگر شما هم نگران عزیزانتا...
# 2      3  BhIjehEFXZ0  .\n@BeKhatereMan\n.\nاگر شما هم نگران عزیزانتا...
# 3      4  BgGYNWABqeh  .\n@BeKhatereMan\n.\nاگر شما هم نگران عزیزانتا...
# 4      5  BgGYMmoBFjd  .\n@BeKhatereMan\n.\nاگر شما هم نگران عزیزانتا...
#
#    like  comment  share  save  reach  pf_visit  follows  impression  \
# 0    58        1      0     0      7         0        0           7
# 1   108        1      0     0      8         0        0           8
# 2    56        0      0     1      2         0        0           2
# 3    30        0      0     0      2         0        0           2
# 4    40        0      0     0      2         1        0           2
#
#         type  image-alt
# 0       logo        NaN
# 1  other_ads        NaN
# 2       logo        NaN
# 3  other_ads        NaN
# 4  other_ads        NaN

# %% [markdown]
# As you can see above my 'post_link' feature contains each post link which we just have to add it to the url we mentioned above to monitor it.
#
# There are two ways to tackle the problem of scraping comments of each post in instagram:
# 1. using selenium library, opening Instagram Web, navigate to our post, retrieve comments for that post via web page source code.
# 2. just use GraphQL and Json :)
#
# Obviously, proper way to doing this is using GraphQL since it's much more faster and actually we need our data in structured format so we can sort it and extract the part we want much easier. the objective is here to make a dataframe which contains useful information about the comments.
#
# To benefit from this method we need to pass a variable dictionary to this hash url:
#
# https://www.instagram.com/graphql/query/?query_hash=97b41c52301f77ce508f55e66d17620e
#
# and if you do it correctly, a json will be passed for you which contains comment information of requested post.
# Variables Dictionary contains:
# 1. short code or url of in-mind post.
# 2. quantity of comments you want to retrieve for each request.
# 3. index of comment you want to recieve after that (when you want to get a post comments in multiple requests.)
#
# Before determining which features we want to have in our dataset regarding comments, we need to see which information are available for us via this way.
#
# Lets just test this method with one of our entries:

# %%
number_of_comments_to_recieve = 50
max_id = ''
get_comment_url = 'https://www.instagram.com/graphql/query/?query_hash=97b41c52301f77ce508f55e66d17620e'

# we can actually define a python dictionary for it.

__variables = {
    "shortcode": str(df_posts['post_link'][0]),
    "first": str(number_of_comments_to_recieve),
    "after": "" if not max_id else max_id
}


# but since we have to pass it as a string via GET method in url, 
# I find it easier to make variables dictonary a string in python before passing it.

variables = '&variables={"shortcode":"' + str(df_posts['post_link'][16]) +'","first":"' + str(number_of_comments_to_recieve) + '","after":"' + max_id + '"}'

json_response = requests.get(get_comment_url + variables).json()
json_response
# Out:
# {'data': {'shortcode_media': {'edge_media_to_parent_comment': {'count': 3,
#     'page_info': {'has_next_page': False, 'end_cursor': None},
#     'edges': [{'node': {'id': '17904030238121618',
#        'text': '@Bekhatereman Kash Ye nega ham be direct haton mindKhtid',
#        'created_at': 1516067351,
#        'did_report_as_spam': False,
#        'owner': {'id': '5986010015',
#         'is_verified': False,
#         'profile_pic_url': 'https://scontent-amt2-1.cdninstagram.com/v/t51.2885-19/s150x150/97543380_248788369665493_8552836172030672896_n.jpg?_nc_ht=scontent-amt2-1.cdninstagram.com&_nc_ohc=gMjxcSK4h7YAX8xlt50&tp=1&oh=9259ba85d7119309b603a358244b8d8d&oe=5FE34193',
#         'username': 'dokhtaram_adrina'},
#        'viewer_has_liked': False,
#        'edge_liked_by': {'count': 0},
#        'edge_threaded_comments': {'count': 0,
#         'page_info': {'has_next_page': False, 'end_cursor': None},
#         'edges': []}}},
#      {'node': {'id': '17919087844025241',
#        'text': 'دوستان گرامی و عزیز ... خسته نباشید و خدا قوت ... منتظر کارها و عکسهای جدید هستیم ...سپاس از شما 🌷🌷🌷🌎🙆😍👍👌',
#        'created_at': 1516072234,
#        'did_report_as_spam': False,
#        'owner': {'id': '719874770',
#         'is_verified': False,
#         'profile_pic_url': 'https://scontent-amt2-1.cdninstagram.com/v/t51.2885-19/s150x150/120197657_736965963828775_5431666852032085471_n.jpg?_nc_ht=scontent-amt2-1.cdninstagram.com&_nc_ohc=z9otHb5jwPMAX8ngHsn&tp=1&oh=95a47b508d23a4de724420b5706ae6fa&oe=5FE2E8FE',
#         'username': 'lady._.designer'},
#        'viewer_has_liked': False,
#        'edge_liked_by': {'count': 0},
#        'edge_threaded_comments': {'count': 0,
#         'page_info': {'has_next_page': False, 'end_cursor': None},
#         'edges': []}}},
#      {'node': {'id': '17905619464085983',
#        'text': '#لعنت_به_ارين_موتور_دزد',
#        'created_at': 1518024840,
#        'did_report_as_spam': False,
#        'owner': {'id': '1730785530',
#         'is_verified': False,
#         'profile_pic_url': 'https://instagram.fauh1-1.fna.fbcdn.net/v/t51.2885-19/44884218_345707102882519_2446069589734326272_n.jpg?_nc_ht=instagram.fauh1-1.fna.fbcdn.net&_nc_ohc=eJfynleCkQkAX8gYnSH&oh=50458465d78e796a4cbbe4be20c341c5&oe=5FE54B0F&ig_cache_key=YW5vbnltb3VzX3Byb2ZpbGVfcGlj.2',
#         'username': 'mania_mind'},
#        'viewer_has_liked': False,
#        'edge_liked_by': {'count': 0},
#        'edge_threaded_comments': {'count': 0,
#         'page_info': {'has_next_page': False, 'end_cursor': None},
#         'edges': []}}}]}}},
#  'status': 'ok'}

# %% [markdown]
# If you are familiar with json you can understand the reply easily, this post had 1 comment we can see its quantity as 'count' field.
#
# each comment will be a 'node' in this json response which everyone of them have an id, comment text, create date, owner and much more useful information.

# %%
id_list = []
owner_username_list = []
text_list = []
comments_retrieved = json_response['data']['shortcode_media']['edge_media_to_parent_comment']['count']
for comment_number in range(comments_retrieved):
    id_list.append(json_response['data']['shortcode_media']['edge_media_to_parent_comment']['edges'][comment_number]['node']['id'])
    owner_username_list.append(json_response['data']['shortcode_media']['edge_media_to_parent_comment']['edges'][comment_number]['node']['owner']['username'])
    text_list.append(json_response['data']['shortcode_media']['edge_media_to_parent_comment']['edges'][comment_number]['node']['text'])
temp_data = {'id' : id_list,
             'owner_username' : owner_username_list,
             'text' : text_list,
             'post_link' : str(df_posts['post_link'][16])
            }
df_test = pd.DataFrame(data = temp_data)
df_test
# Out:
#                   id    owner_username  \
# 0  17904030238121618  dokhtaram_adrina
# 1  17919087844025241   lady._.designer
# 2  17905619464085983        mania_mind
#
#                                                 text    post_link
# 0  @Bekhatereman Kash Ye nega ham be direct haton...  Bd-qCY4lATh
# 1  دوستان گرامی و عزیز ... خسته نباشید و خدا قوت ...  Bd-qCY4lATh
# 2                            #لعنت_به_ارين_موتور_دزد  Bd-qCY4lATh

# %% [markdown]
# now we can make our dataframe, in order to make this code cleaner we will write a function to first iterate for each post in our dataset and then iterate all comments in that post and save it to the new dataset we will make.

# %% [markdown]
# here I'm creating my empty lists for next function.

# %%
id_list = []
owner_username_list = []
text_list = []
post_link_list = []

# %%
def comment_retriever(post_link = df_posts['post_link'], start_index = 0):
    '''
    this function is designed to retrieve all comments for an Instagram post which you will pass short code to this function.
    args:
        post_link -> short link of the post you want to retrieve its comments.
        start_index -> since i have connection issue i retrieve start point from user
    return:
        this function actually returns nothing but update lists which we make our dataframe from them gradually.
    '''
    url = 'https://www.instagram.com/graphql/query/?query_hash=97b41c52301f77ce508f55e66d17620e&'
    code = 'ramin :)'
    for i in range(start_index, len(post_link)):
        code = post_link[i]
        variables = 'variables={"shortcode":"' + code + '","first":"50","after":""}'
        req_url = url + variables
        json_response = requests.get(req_url).json()
        cm_retrieved = json_response['data']['shortcode_media']['edge_media_to_parent_comment']['count']
        print(f"{i}, Response Status: {json_response['status']}, post shortcode: {code}")
        print(f"comments retrieved for this post: {cm_retrieved}")
        if cm_retrieved == 0:
            continue
        else:
            for cm in json_response['data']['shortcode_media']['edge_media_to_parent_comment']['edges']:
                id_list.append(cm['node']['id'])
                owner_username_list.append(cm['node']['owner']['username'])
                text_list.append(cm['node']['text'])
                post_link_list.append(code)
        print(f"items post {i} added to the related lists.")
    return None

# %%
comment_retriever(start_index = 204)
# Out:
# 204, Response Status: ok, post shortcode: BYgQJ3YF-VB
# comments retrieved for this post: 0
# 205, Response Status: ok, post shortcode: BYgQITdlLGm
# comments retrieved for this post: 0
# 206, Response Status: ok, post shortcode: BYgQFmqloOv
# comments retrieved for this post: 0
# 207, Response Status: ok, post shortcode: BYfgOT0FSA2
# comments retrieved for this post: 0
# 208, Response Status: ok, post shortcode: BYfgKstlYil
# comments retrieved for this post: 1
# items post 208 added to the related lists.
# 209, Response Status: ok, post shortcode: BYfgEzWlAZD
# comments retrieved for this post: 0
# 210, Response Status: ok, post shortcode: BYdth45FLRh
# comments retrieved for this post: 0
# 211, Response Status: ok, post shortcode: BYdtd57F3Rf
# comments retrieved for this post: 2
# items post 211 added to the related lists.
# 212, Response Status: ok, post shortcode: BYdtbKXFCOr
# comments retrieved for this post: 0
# 213, Response Status: ok, post shortcode: BYdtUBhlSnS
# comments retrieved for this post: 4
# items post 213 added to the related lists.
# 214, Response Status: ok, post shortcode: BYdtR-4lyAQ
# comments retrieved for this post: 1
# items post 214 added to the related lists.
# 215, Response Status: ok, post shortcode: BYdtOdFlWuO
# comments retrieved for this post: 0
# 216, Response Status: ok, post shortcode: BYc9_3vlYay
# comments retrieved for this post: 0
# 217, Response Status: ok, post shortcode: BYc99b9lRmx
# comments retrieved for this post: 0
# 218, Response Status: ok, post shortcode: BYc95eiFJfH
# comments retrieved for this post: 0
# 219, Response Status: ok, post shortcode: BYbMPcWFt2D
# comments retrieved for this post: 1
# items post 219 added to the related lists.
# 220, Response Status: ok, post shortcode: BYbMJv9lfgn
# comments retrieved for this post: 0
# 221, Response Status: ok, post shortcode: BYbLz-JljGJ
# comments retrieved for this post: 0
# 222, Response Status: ok, post shortcode: BYaguJvFaMn
# comments retrieved for this post: 0
# 223, Response Status: ok, post shortcode: BYagq8hFGyG
# comments retrieved for this post: 1
# items post 223 added to the related lists.
# 224, Response Status: ok, post shortcode: BYagn9rFymv
# comments retrieved for this post: 1
# items post 224 added to the related lists.
# 225, Response Status: ok, post shortcode: BYYiSYClYnh
# comments retrieved for this post: 0
# 226, Response Status: ok, post shortcode: BYYiPxSF3Uq
# comments retrieved for this post: 0
# 227, Response Status: ok, post shortcode: BYYiNZKFHTA
# comments retrieved for this post: 0
# 228, Response Status: ok, post shortcode: BYYiJ3dFZSg
# comments retrieved for this post: 1
# items post 228 added to the related lists.
# 229, Response Status: ok, post shortcode: BYYiHMOl6VA
# comments retrieved for this post: 0
# 230, Response Status: ok, post shortcode: BYYh-B_lr-S
# comments retrieved for this post: 0
# 231, Response Status: ok, post shortcode: BYX0u27FPI5
# comments retrieved for this post: 7
# items post 231 added to the related lists.
# 232, Response Status: ok, post shortcode: BYX0mE-FQyc
# comments retrieved for this post: 3
# items post 232 added to the related lists.
# 233, Response Status: ok, post shortcode: BYX0kgQFx3H
# comments retrieved for this post: 0
# 234, Response Status: ok, post shortcode: BYV-ZwQlYT4
# comments retrieved for this post: 0
# 235, Response Status: ok, post shortcode: BYV-UfpluWv
# comments retrieved for this post: 0
# 236, Response Status: ok, post shortcode: BYV-NRxFUY_
# comments retrieved for this post: 0
# 237, Response Status: ok, post shortcode: BYVbbaJFiId
# comments retrieved for this post: 0
# 238, Response Status: ok, post shortcode: BYVbWDUl6sA
# comments retrieved for this post: 2
# items post 238 added to the related lists.
# 239, Response Status: ok, post shortcode: BYVbLQlFPI-
# comments retrieved for this post: 6
# items post 239 added to the related lists.
# 240, Response Status: ok, post shortcode: BYVXWj9FhJ0
# comments retrieved for this post: 1
# items post 240 added to the related lists.
# 241, Response Status: ok, post shortcode: BYVXTWVF1kz
# comments retrieved for this post: 1
# items post 241 added to the related lists.
# 242, Response Status: ok, post shortcode: BYVXPhrlc2s
# comments retrieved for this post: 0
# 243, Response Status: ok, post shortcode: BYTWmKKlTCO
# comments retrieved for this post: 0
# 244, Response Status: ok, post shortcode: BYTWj4dlDG2
# comments retrieved for this post: 0
# 245, Response Status: ok, post shortcode: BYTWfualxLZ
# comments retrieved for this post: 3
# items post 245 added to the related lists.
# 246, Response Status: ok, post shortcode: BYShqHXlXMj
# comments retrieved for this post: 3
# items post 246 added to the related lists.
# 247, Response Status: ok, post shortcode: BYShgvlFX4J
# comments retrieved for this post: 1
# items post 247 added to the related lists.
# 248, Response Status: ok, post shortcode: BYShZ-XFTHW
# comments retrieved for this post: 3
# items post 248 added to the related lists.
# 249, Response Status: ok, post shortcode: BYQ7UT1FYzu
# comments retrieved for this post: 0
# 250, Response Status: ok, post shortcode: BYQ7Qsal_zA
# comments retrieved for this post: 0
# 251, Response Status: ok, post shortcode: BYQ7NfClOKt
# comments retrieved for this post: 2
# items post 251 added to the related lists.
# 252, Response Status: ok, post shortcode: BYQKZy_FaWx
# comments retrieved for this post: 0
# 253, Response Status: ok, post shortcode: BYQKU5MFxQk
# comments retrieved for this post: 4
# items post 253 added to the related lists.
# 254, Response Status: ok, post shortcode: BYQKOQ1FaI0
# comments retrieved for this post: 0
# 255, Response Status: ok, post shortcode: BYOO6h7lScF
# comments retrieved for this post: 0
# 256, Response Status: ok, post shortcode: BYOO0U3llWZ
# comments retrieved for this post: 8
# items post 256 added to the related lists.
# 257, Response Status: ok, post shortcode: BYOOrbYFm1j
# comments retrieved for this post: 0
# 258, Response Status: ok, post shortcode: BYNoiGTl0kv
# comments retrieved for this post: 2
# items post 258 added to the related lists.
# 259, Response Status: ok, post shortcode: BYNofRClPpj
# comments retrieved for this post: 0
# 260, Response Status: ok, post shortcode: BYNoY2ulFHw
# comments retrieved for this post: 0
# 261, Response Status: ok, post shortcode: BYLrJi4FRce
# comments retrieved for this post: 2
# items post 261 added to the related lists.
# 262, Response Status: ok, post shortcode: BYLqhAJl2Jz
# comments retrieved for this post: 4
# items post 262 added to the related lists.
# 263, Response Status: ok, post shortcode: BYLqbmnFhsj
# comments retrieved for this post: 3
# items post 263 added to the related lists.
# 264, Response Status: ok, post shortcode: BYK0S9Mlr5K
# comments retrieved for this post: 0
# 265, Response Status: ok, post shortcode: BYKz92pFZvx
# comments retrieved for this post: 4
# items post 265 added to the related lists.
# 266, Response Status: ok, post shortcode: BYKyeA5l_rQ
# comments retrieved for this post: 0
# 267, Response Status: ok, post shortcode: BYJFqnjliJw
# comments retrieved for this post: 3
# items post 267 added to the related lists.
# 268, Response Status: ok, post shortcode: BYJFiCwFr-r
# comments retrieved for this post: 0
# 269, Response Status: ok, post shortcode: BYJFcnwlUjV
# comments retrieved for this post: 0
# 270, Response Status: ok, post shortcode: BYIk54WlSaH
# comments retrieved for this post: 0
# 271, Response Status: ok, post shortcode: BYIk2XplkpN
# comments retrieved for this post: 0
# 272, Response Status: ok, post shortcode: BYIkzSmlMNm
# comments retrieved for this post: 1
# items post 272 added to the related lists.
# 273, Response Status: ok, post shortcode: BYGkf7xlFwq
# comments retrieved for this post: 0
# 274, Response Status: ok, post shortcode: BYGkY_5Fdoc
# comments retrieved for this post: 3
# items post 274 added to the related lists.
# 275, Response Status: ok, post shortcode: BYGjkjlFC4M
# comments retrieved for this post: 0
# 276, Response Status: ok, post shortcode: BYF6-pllBGk
# comments retrieved for this post: 3
# items post 276 added to the related lists.
# 277, Response Status: ok, post shortcode: BYF67OzFhCy
# comments retrieved for this post: 1
# items post 277 added to the related lists.
# 278, Response Status: ok, post shortcode: BYF62OOF4E4
# comments retrieved for this post: 1
# items post 278 added to the related lists.
# 279, Response Status: ok, post shortcode: BYD8708F-uS
# comments retrieved for this post: 0
# 280, Response Status: ok, post shortcode: BYD8056loTm
# comments retrieved for this post: 2
# items post 280 added to the related lists.
# 281, Response Status: ok, post shortcode: BYD8xddlS-m
# comments retrieved for this post: 0
# 282, Response Status: ok, post shortcode: BYDSWxdFlop
# comments retrieved for this post: 0
# 283, Response Status: ok, post shortcode: BYDSQ-lFR9Z
# comments retrieved for this post: 3
# items post 283 added to the related lists.
# 284, Response Status: ok, post shortcode: BYDRtrBlVVN
# comments retrieved for this post: 0
# 285, Response Status: ok, post shortcode: BYBYZVUFp2O
# comments retrieved for this post: 0
# 286, Response Status: ok, post shortcode: BYBYRuNldK1
# comments retrieved for this post: 0
# 287, Response Status: ok, post shortcode: BYBYOFkF3jA
# comments retrieved for this post: 1
# items post 287 added to the related lists.
# 288, Response Status: ok, post shortcode: BYAofZnlUbH
# comments retrieved for this post: 0
# 289, Response Status: ok, post shortcode: BYAoZYcl_XA
# comments retrieved for this post: 8
# items post 289 added to the related lists.
# 290, Response Status: ok, post shortcode: BYAoPfdlirU
# comments retrieved for this post: 2
# items post 290 added to the related lists.
# 291, Response Status: ok, post shortcode: BX-29i4FsTo
# comments retrieved for this post: 0
# 292, Response Status: ok, post shortcode: BX-21fUl0El
# comments retrieved for this post: 2
# items post 292 added to the related lists.
# 293, Response Status: ok, post shortcode: BX-2K5lltzn
# comments retrieved for this post: 0
# 294, Response Status: ok, post shortcode: BX-VtlHln9Q
# comments retrieved for this post: 0
# 295, Response Status: ok, post shortcode: BX-VYgBlzZZ
# comments retrieved for this post: 0
# 296, Response Status: ok, post shortcode: BX-VP4vl3Sl
# comments retrieved for this post: 0
# 297, Response Status: ok, post shortcode: BX8J4KDlTYN
# comments retrieved for this post: 11
# items post 297 added to the related lists.
# 298, Response Status: ok, post shortcode: BX8J1dCFyrP
# comments retrieved for this post: 0
# 299, Response Status: ok, post shortcode: BX8JyFSF6UO
# comments retrieved for this post: 0
# 300, Response Status: ok, post shortcode: BX3QCC9lJNO
# comments retrieved for this post: 5
# items post 300 added to the related lists.
# 301, Response Status: ok, post shortcode: BX3PxRwFqyD
# comments retrieved for this post: 15
# items post 301 added to the related lists.
# 302, Response Status: ok, post shortcode: BX3PLh3loQA
# comments retrieved for this post: 0
# 303, Response Status: ok, post shortcode: BX1-kcuFzM9
# comments retrieved for this post: 11
# items post 303 added to the related lists.
# 304, Response Status: ok, post shortcode: BXiJmDQlwz1
# comments retrieved for this post: 1
# items post 304 added to the related lists.
# 305, Response Status: ok, post shortcode: BXiJkDJl5ee
# comments retrieved for this post: 2
# items post 305 added to the related lists.
# 306, Response Status: ok, post shortcode: BXiJjg8Fpzp
# comments retrieved for this post: 5
# items post 306 added to the related lists.
# 307, Response Status: ok, post shortcode: BXiJgZuFGQf
# comments retrieved for this post: 2
# items post 307 added to the related lists.
# 308, Response Status: ok, post shortcode: BXiJd9YF6bY
# comments retrieved for this post: 0
# 309, Response Status: ok, post shortcode: BXfQ6Y9Fv7k
# comments retrieved for this post: 0
# 310, Response Status: ok, post shortcode: BXfQ4qKFXw_
# comments retrieved for this post: 0
# 311, Response Status: ok, post shortcode: BXfQ17eFqlS
# comments retrieved for this post: 0
# id list is: ['17925563803134203', '17857688434300045', '17912877673509433', '17939183302119902', '17921061856066364', '17921061856066364', '17862110648164087', '17920898326097139', '17923357123036506', '17909428336112283', '17849068873241899', '17923624600044216', '17950442155029879', '17939205487115110', '17901974563083689', '17897392606188328', '17901974563083689', '17897392606188328', '17904030238121618', '17919087844025241', '17905619464085983', '17924299621095763', '17892313873169793', '17864449705202502', '17888640193149396', '17923888360002961', '17914348681011943', '17902101943097203', '17908714852021412', '17908750894028838', '17890151422084507', '17873209858168266', '17842890709213371', '17875969993154222', '17843999746222539', '17864776594195383', '17876746942166117', '17905017835003466', '17901575749031734', '17873014081173707', '17900665951016031', '17844190435207901', '17881289863143853', '17900404378003228', '17860597933194061', '17885635756087617', '17902115506052326', '17900689957012038', '17874908011146363', '17874410092152719', '17900647180058183', '17887719649104475', '17884232710081152', '17875709434189210', '17874863131184116', '17894374927071097', '17899673062013568', '17874601582180131', '17874068074167385', '17885016670083432', '17900977996062958', '17891273890076184', '17887987006101492', '17899696171014120', '17884307911085182', '17900196157017235', '17886302650121968', '17873720296165606', '17888265106129390', '17875163266151328', '17886535918121283', '17874435925176710', '17842485622204917', '17887885513102187', '17842413880216531', '17890220593107005', '17892218719074716', '17873428669160401', '17873382781167010', '17899785418062326', '17875332172187705', '17888428171129955', '17900610646020691', '17872398811170406', '17884495135083218', '17900309335026835', '17901386707034038', '17886657112124215', '17872547848172847', '17899809673029924', '17900358907034096', '17889933994117329', '17885566627092203', '17886094222093047', '17845228597202120', '17845028713203735', '17887754620113633', '17843511625202636', '17887797499096349', '17887483381128872', '17899700422006622', '17887827940106117', '17871951010173225', '17900812675006545', '17900047171057435', '17900137858028026', '17901201721027472', '17893441306074588', '17902258789027141', '17889998458741191', '17887608991107089', '17898923896052738', '17887367704105959', '17884113736093943', '17899575370036471', '17898979204061693', '17899525519036672', '17875039069192032', '17900213917059889', '17899934956044459', '17899454761025723', '17899975099054215', '17890334122078171', '17899743817062124', '17872630063166179', '17871562498168470', '17885837743127076', '17899609054062257', '17873735977178998', '17898865753010103', '17875726156133385', '17875733551141793', '17887128658105995', '17874169339159321', '17887405465111990', '17875015579146514', '17888244250097491', '17890342165074735', '17898862681021599', '17884202314092387', '17895357931070794', '17888258617103796', '17901530545028753', '17874681082150622', '17884117153094810', '17891636755075273', '17884219636087465', '17873670211193712', '17874521986180187', '17874805243148497', '17875626817184130', '17899894945018545', '17886789379123886', '17899642354029970', '17899706995025689', '17900271088033312', '17900845726030787', '17886582784122892', '17874892678148055', '17899896217023418', '17900013484024462', '17888127934099438', '17884293805080699', '17884383226081022', '17889106804098459', '17872422346174180', '17900607520039051', '17887721152109163', '17900061835056963', '17884333375080542', '17877002308141117', '17875619407190697', '17894133712070487', '17874506194152462', '17884197604095049', '17876082298187796', '17884608370085742', '17900264056028849', '17887622617117395', '17886550294122393', '17884213495092462', '17887184881109079', '17899483369000257', '17901142837047629', '17876598847153188', '17890655494075550', '17893424542068778', '17900244379013579', '17898995773017045', '17883173842083584 ...
# owner username list is: ['antalya_amlak_best', 'pariyanikookar', 'lady._.designer', 'originalshow', 'qn_mkc', 'qn_mkc', 'lady._.designer', 'shabnam.sv_', 'cilajet', 'mania_mind', 'mania_mind', 'mania_mind', 'originalshow', 'originalshow', '_ladymahsa_', 'mania_mind', '_ladymahsa_', 'mania_mind', 'dokhtaram_adrina', 'lady._.designer', 'mania_mind', 'shabnam.sv_', 'mania_mind', 'mania_mind', 'dokhtaram_adrina', 'mania_mind', 'aycel_queen', 'liana.meshkin', 'amir966558', 'prince____adrian', 'dokhtaram_adrina', 'mina.nori__', 'paris.jr.t', 'p_gha1360', 'qn_mkc', 'pisc_pt', 'dokhtaram_adrina', 'sara.ahmadiannn', 'ifyoutheni', 'piercing_sude', 'qn_mkc', 'farhan23kh', 'director.exe', 'mohammadali._.w124', 'kimiya6957', 'qn_mkc', 'pisc_pt', 'num1maya', 'aliespix', 'taranom_s97', 'qn_mkc', 'piercing_sude', 'parisaarah', 'amirali.sharbati', 'rosha.barad.life', 'mino_hhhhhhhh', 'banoye.shahrivariii', 'masiha_ghi', 'masiha_majidi', 'masiha_majidi', 'setare_ahmdii', 'aycel_queen', 'masome__68', 'num1maya', 'masome__68', 'masome__68', 'ghand_.o._asal', 'qn_mkc', 'qn_mkc', 'amirali.sharbati', 'amirali.sharbati', 'amirali.sharbati', 'masiha_ghi', 'ahmad.a38', 'masiha_majidi', 'ahmad.a38', 'arashdc', 'num1maya', 'taranom_s97', 'robabehmeshkani', 'memory_mn_', 'ghand_.o._asal', 'sari.gol', 'bita_s.a.n', 'lady._.designer', 'liiiida.nz', 'banoye.shahrivariii', 'masiha_ghi', 'mina.nori__', 'mina.nori__', 'aliespix', 'farshad.avare7586', 'nini.naz_21', 'gallerygonesh', '_roya_46', 'farshad.avare7586', 'yasna951012', 'nini.naz_21', 'lili.eshgham', 'pouria_si_', 'sam098098', 'lady._.designer', 'lady._.designer', 'aramsachfr', 'aisa_nasr', 'lady._.designer', 'lady._.designer', 'ehsanhosseinpour85', 'lady._.designer', 'lady._.designer', 'n4ghmak', 'nazaninheesami', 'bita_s.a.n', 'bita_s.a.n', 'bita_s.a.n', 'yalda_s_alinejhad', 'nusin_taskin', 'bita_s.a.n', 'bita_s.a.n', 'bita_s.a.n', 'aliespix', 'babylove_best', 'usernamees__', 'fereshte_7266', 'esme.khaas', 'arghavan.goliii', 'buy_basababa', 'fereshte_7266', 'samiraborji_makeup', 'marzi.60.60', 'barangharib_60', 'aliespix', 'naeem_bostano', 'zohre.8322', 'mehrbanoo69h', 'zohre.8322', 'bahargern', 'ghand_.o._asal', 'adeleh.nik.25', 'ghand_.o._asal', 'woody.shoody', 'woody.shoody', 'woody.shoody', 'woody.shoody', 'woody.shoody', 'woody.shoody', 'woody.shoody', 'woody.shoody', 'woody.shoody', 'woody.shoody', 'woody.shoody', 'woody.shoody', 'woody.shoody', 'salehy1990', 'woody.shoody', 'woody.shoody', 'kourosh.safari.iran', 'am_ir627', 'saharjavahery', 'sepid.saee', 'sepid.saee', 'sepid.saee', 'sepid.saee', 'sepid.saee', 'sepid.saee', 'sepid.saee', 'sepid.saee', 'sepid.saee', 'sepid.saee', 'sepid.saee', 'sepid.saee', 'sepid.saee', 'sepid.saee', 'sepid.saee', 'amirshekofteh552017', 'amirshekofteh552017', 'masoud.karemy', 'm.s8048', 'abrahimi8988', '92taha05', 'home.pelus', 'somali7lang', 'aycel_queen', 'mahyarmom', 'ehsan.kazemikhah', 'piercing_sude', 'abade.shopping', 'lnaz5', 'abade.shopping', 'mitra.m.sh.50', 'bita_s.a.n', 'ghand_.o._asal', 'giti307876', 'korooshhejazi', 'thenimaa', 'ayyyyliiiinn', 'negar_motamedii', 'hesam7motamedi', 'qn_mkc', 'hadi__as77', 'ahoora5552546', 'korooshhejazi', 'bayi_lucu_cute', 'bayi_lucu_cute', 'bayi_lucu_cute', 'hajar5990', 'zahra._kb', 'daity341', 'giti307876', 'nozgol', 'amirsina.khodadadi', 'amirsina.khodadadi', 'mina.nori__', 'masiha_ghi', 'nazaninamasali', 'helenaa733', 'bt_123_', 'aliespix', 'm_imo63', 'neginn_1369', 'nozgol', 'tannaz.afra', 'mojganafkhami', 'barangharib_60', '1365s222', 'sam098098', 'happy__coder', 'ilyad.mazaheri', 'rf.r35', 'mitra_fallahi', 'fatemedinarvand', 'minaabbasi49142015', '_____.pariya', 'foroogh_ahmaddoost', 'arianarjabadi', 'mahnaz.najafi86', 'aidaaidini', 'faatma.sabet', 'mitra_fallahi', 'r_t_dost', 'laleh_mina', 'ashkan.gh0636', 'prince_arshan_official', 'minaabbasi49142015', 'n.abharakpour', 'n.abharakpour', 'n.abharakpour', 'fateme.916', '69afsaneh21', 'bahrami.parisa584', 'asal56561007', 'sam098098', 'faezeh_2c', 'unknown_accoun ...
# text list is: ['برای دریافت بهترین قیمتهای املاک در آنتالیا ترکیه به پیج من سر بزنید', 'عالی بود لایک داره😍👍', '👍👌SUPER😍LIKE👌👍', 'پیج تون فوق العاده س😍', 'سلام مسابقہ جدیدہ؟', 'سلام مسابقہ جدیدہ؟', '👍👌SUPER😍EXCELLENT👌👍', '👍👍👍', '👍👍', 'لعنت به ازين موتور دزد', 'لعنت به ارين موتور دزد', 'لعنت به ارين موتور دزد', 'عالی 😍😍😍👍😍', 'عالی 😍😍😍👍😍', 'همیشه پرانرژی باشید', '#لعنت_به_ارين_موتو_دزد', 'همیشه پرانرژی باشید', '#لعنت_به_ارين_موتو_دزد', '@Bekhatereman Kash Ye nega ham be direct haton mindKhtid', 'دوستان گرامی و عزیز ... خسته نباشید و خدا قوت ... منتظر کارها و عکسهای جدید هستیم ...سپاس از شما 🌷🌷🌷🌎🙆😍👍👌', '#لعنت_به_ارين_موتور_دزد', 'عالی 😍😍😍👍😍', '#لعنت_به_ارين_موتور_دزد', '#لعنت_به_ارين_موتور_دزد', 'Be directeton Sar beznid', '#لعنت_به_ارين_موتور_دزد', 'آگه زحمتی نیست دایرکتاتون چک کنید', '🙏👍', 'سلام خوبید مسابقه شروع شده??', '✌ ✌ ✌ ✌', 'سلام شبتون بخیر. من براتون دایرکت فرستادم لطفا چک کنید', 'مگه مسابقه تموم نشد؟؟؟؟', 'مگه هنوز وقت داره؟', 'چرا جوایز رو نمیدی', 'جایزه من را ندادین', 'از پیج آموزشی ما هم دیدن کنید💪💎', 'سلام دوست عزیز لطفا دایرکت چک کنید', 'واقعا پیج زیبایی دارین خیلی خوشحالم که میبینم واقعا فرهنگمون داره بهتر میشه. فقط یه خواهشی از دوستان داشتم خیلی میبینم نی نی هاشون رو بجای اینکه رو صندلی مخصوص کودک بنشونن تو بغلشون نگه میدارن موقع رانندگی تو رو خدا فکر خودتون نیستین فکر اون طفل معصومتون باشین .', 'So cute!', '@bekhatereman مگه یبار اسامی رو اعلام نکردین؟؟؟؟از اول؟؟؟؟', 'چه قشنگ بود این فیلم', 'Fb', 'اسم بازي چي بود😂😂😂', 'ممنون از شما و پیج تون .هدیه تون به دستم رسید ، امیدوارم فرهنگ های خوب رانندگی روز ب روز بیشتر در ایران نهادینه بشه', 'این پستای جدید که برای شرکت در مسابقه #بخاطرمن گذاشتین به معنی این هست که دوباره مسابقه دارید؟', 'جایزه من نیمده ادمین جان', 'همیشه میتسوبیشی دوس داشتم❤', 'مبارکتون باشه', 'ممنون از لطفتان @bekhatereman', '@aliespix مبارکتون باشه', 'علی جان مبارکه @aliespix', '@bekhatereman واقعا که از شما بعیده...حرف خودتون رو نقض کردین قرار به قرفه کشی بود و خیلی از متن و عکس ها بهتر از اینایی بود که شما انتخاب کردین', 'سپاسگذارم 🙏', 'آخي پسر کوچولوی من اولين کسی بود که در کمپین شما شرکت کرد، موفق باشید', 'خيلي كج سليقه هستين !!!!! قرار بود نگاه كسي كه در عكس هست به دوربين باشه و كپشن خوب داشته باشه !!! طبق معمول همه مسابقات اينستا و پيجهاي ايراني !! بايد هم همين انتظار رو ميداشتيم ، موفق باشين', 'نگفته بودید لایکی هست وگرنه لایک جمع میکردیم .', 'مگه قرار نبود قرعه کشی کنید', 'چند تا از عکس ها اصلا به دوربین نکردن .انتخاب رو میداید به کسی که شرایط مسابقه رو گذاشته بود .', 'اینجام شد پارتی بازی', 'با کمپین فالورهاتونو به دو هزار رسوندین. شرایط انتخابتونم عوض کردین. لطفا عکس ارسالی بنده رو از پیجتون پاک کنین.', 'جامعه حمایت از بیماران دیستروفی عضلانی@dystrophy_society', 'اگر همه عکس ها همزمان میذاشتید اونوقت مشخص بود کدام عکس بیشترین لایک جمع کرده تصویر های اخیر لایک های کمتر دارند چون دیر گذاشته شد.', 'سلام پس بهترین عکس چی', 'مبارکتون باشه', 'دوستمون درست میگه بیشترین لایک برا اونایی ک اول بودم', 'ن', 'بازم چک کنید منم خیلی لایک داره عکسم', 'ممنون 😍😍😍😍😍😍', '@aliespix مرسی دوست با معرفت و خوبم', 'قرار بود به بهترین کپشن به نظر دورانتان جایزه تعلق بگيره نه به بیشترین لایک ها', 'شاید خودتون هم فراموش کردید روال کمپین چی بوده، چون نوشته بودید عکسی از خودتون که به دوربین نگاه کنید و از عزیزترین شخص بخواهید که هنگام رانندگی...، اما عکسهای برنده بعضا اصلا تصویر شخص نیست که به دوربین نگاه کرده باشه', 'درهرصورت براتون آرزوی موفقیت میکنم و امیدوارم در کمپین های بعدی شرایط اجرایی کمپین به نحوی باشه که نقض کننده حرفهای خودتون نباشه', 'چرا قرعه کشی نکردید .اگه لایکی بود میگفتید که لایکی هست .', 'جایزه چیه', 'واقعا که! بعضی از عکسا اصلا معلوم نیست چی به چین! اصلا تصویر نیست.', 'سلام دوستان موجودی کارت هدیه فرستاده شده چقدره', 'مچكرم از شما اول به خاطر حركت فرهنگي بسيار خوبتون سپس بابت هديه 🙏🏻🌹❤️', 'مبارک تون باشه', 'مبارکشون باشه ولی متن منم قشنگ بوداااااا🌷', 'ای کاش یه بخش قرعه کشیم داشتید😐😐', 'تشکر از شما 🙏💮', 'پس عکس من یعنی جزعه هیچکدوم نبود؟؟', 'سپاس بی نهایت ⚘⚘⚘', 'سپاس بابت انتخاب من و هدیه،  اما برنده اصلی شما و همکارانتون هستید که اینگونه فرهنگ سازی میکنید و با این کار و آگاهی رسانیتون حتی اگر جان  ...

# %% [markdown]
# now we save our dataframe to an excel file.

# %%
df_comments = pd.DataFrame(data = {'id' : id_list,
                                 'owner_username' : owner_username_list,
                                 'text' : text_list,
                                 'post_link' : post_link_list
                                })
df_comments.to_excel(excel_writer = "data\comments.xlsx")

# %% [markdown]
# in order to make our dataset more comprehensive, we try to save the newly created comments dataset as a new sheet with coresponding name in our main dataset.

# %%
df_comment = pd.read_excel('data/comments.xlsx')
df_comment
# Out:
#      Unnamed: 0                 id       owner_username  \
# 0             0  17925563803134203   antalya_amlak_best
# 1             1  17857688434300045       pariyanikookar
# 2             2  17912877673509433      lady._.designer
# 3             3  17939183302119902         originalshow
# 4             4  17921061856066364               qn_mkc
# ..          ...                ...                  ...
# 402         402  17880543517122587    artin_momy_441392
# 403         403  17886281512077000    artin_momy_441392
# 404         404  17894445739041719    artin_momy_441392
# 405         405  17880883009126319  hedieh_hedayatzadeh
# 406         406  17869301524159205            z.j_89.93
#
#                                                   text    post_link
# 0    برای دریافت بهترین قیمتهای املاک در آنتالیا تر...  BhIjjhfFy7k
# 1                                 عالی بود لایک داره😍👍  BhIjhiuF0Ip
# 2                                       👍👌SUPER😍LIKE👌👍  BfqQTe9FHvR
# 3                                پیج تون فوق العاده س😍  BfqQSf3lsml
# 4                                   سلام مسابقہ جدیدہ؟  BfbUhNxlzaJ
# ..                                                 ...          ...
# 402                          خي من قربونت برم زيبا😍😍😍😍  BXiJjg8Fpzp
# 403                                               💖💖💖💖  BXiJjg8Fpzp
# 404                                               🌹🌹🌹🌹  BXiJjg8Fpzp
# 405    قربووووووونش بشم بانمک دوست داشتنی👌👌👌😄😄😄😉😉❤💙💚💛💜  BXiJgZuFGQf
# 406                                     خدایا قیافشو😄😘  BXiJgZuFGQf
#
# [407 rows x 5 columns]

# %%
book = load_workbook('data/MSc_Thesis_Dataset.xlsx')
writer = pd.ExcelWriter('data/MSc_Thesis_Dataset.xlsx', engine='openpyxl') 
writer.book = book

writer.sheets = dict((ws.title, ws) for ws in book.worksheets)
df_comment.to_excel(writer, "Comments")
writer.save()

# %% [markdown]
# now our we have comment sheet in our main dataset which contains our comments.
#
# the last part of data that we need scraper to complete our dataset, is alts for posts.
# Instagram use image recognition in every post in which tells you what objects are in the picture, this feature is available to access from Instagram web api, in alt tag of image. in this section we are going to retrieve this content from mentioned source and save it in our dataset.
#
# since viewing a post requires login, I found it easier to use selenium and login via it.

# %%
df_posts = pd.read_excel('data/MSc_Thesis_Dataset.xlsx')
df_posts
# Out:
#      index    post_link                                            caption  \
# 0        1  BhIjjhfFy7k  .\n@BeKhatereMan\n.\nاگر شما هم نگران عزیزانتا...
# 1        2  BhIjhiuF0Ip  .\n@BeKhatereMan\n.\nاگر شما هم نگران عزیزانتا...
# 2        3  BhIjehEFXZ0  .\n@BeKhatereMan\n.\nاگر شما هم نگران عزیزانتا...
# 3        4  BgGYNWABqeh  .\n@BeKhatereMan\n.\nاگر شما هم نگران عزیزانتا...
# 4        5  BgGYMmoBFjd  .\n@BeKhatereMan\n.\nاگر شما هم نگران عزیزانتا...
# ..     ...          ...                                                ...
# 307    308  BXiJgZuFGQf  .@BeKhatereMan\n.\nمنم یک روزی یک مرد بزرگ و م...
# 308    309  BXiJd9YF6bY  .@BeKhatereMan\n.\nنه زمین خوردن، نه شکستن اسب...
# 309    310  BXfQ6Y9Fv7k  .@BeKhatereMan\n.\nاگر شما هم نگران عزیزانتان ...
# 310    311  BXfQ4qKFXw_  .@BeKhatereMan\n.\nاگر شما هم نگران عزیزانتان ...
# 311    312  BXfQ17eFqlS  .@BeKhatereMan\n.\nاگر شما هم نگران عزیزانتان ...
#
#      like  comment  share  save  reach  pf_visit  follows  impression  \
# 0      58        1      0     0      7         0        0           7
# 1     108        1      0     0      8         0        0           8
# 2      56        0      0     1      2         0        0           2
# 3      30        0      0     0      2         0        0           2
# 4      40        0      0     0      2         1        0           2
# ..    ...      ...    ...   ...    ...       ...      ...         ...
# 307   109        2      0     1      0         0        0           0
# 308   104        0      0     0      0         0        0           0
# 309    61        0      0     0      0         0        0           0
# 310    57        0      0     0      0         0        0           0
# 311    62        0      0     0      0         0        0           0
#
#             type  image-alt
# 0           logo        NaN
# 1      other_ads        NaN
# 2           logo        NaN
# 3      other_ads        NaN
# 4      other_ads        NaN
# ..           ...        ...
# 307  situational        NaN
# 308  situational        NaN
# 309         logo        NaN
# 310         logo        NaN
# 311         logo        NaN
#
# [312 rows x 13 columns]

# %%
class InstagramBot:
    def __init__(self, username: str, password: str) -> None:
        self.username = username
        self.password = password
        self.driver = webdriver.Chrome('./chromedriver.exe')
        self.base_url = 'https://www.instagram.com'
        pass
    
    def delay(self, t = int) -> None:
        time.sleep(t)
        pass
        
    def login(self) -> None:
        self.driver.get(f'{self.base_url}/accounts/login/')
        self.delay(1)
        # accepting cookie
#         self.driver.find_element_by_xpath('/html/body/div[2]/div/div/div/div[2]/button[1]').click()
        self.driver.find_element_by_name('username').send_keys(self.username)
        self.driver.find_element_by_name('password').send_keys(self.password)
        self.driver.find_element_by_xpath('//*[@id="loginForm"]/div/div[3]/button').click()
        self.delay(1.5)
        pass
        
    def nav_post(self, post_link: str) -> None:
        self.delay(1)
        url = f'{self.base_url}/p/{post_link}/'
        self.driver.get(url)
        self.delay(1)
        pass
    
    def retrieve_alt(self) -> str:
        self.delay(1)
        try:
            return self.driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div[1]/article/div[2]/div/div/div[1]/img').get_attribute('alt')
        except NoSuchElementException:
            return self.driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div[1]/article/div[2]/div/div[1]/div[1]/div[1]/img').get_attribute('alt')

# %% [markdown]
# before inserting into the dataset, it's better to create a data structure containing propriate alt text + post link then add it to the dataframe.
# (list containing tuple which is double pair of link and its alt) - (for first step we are going to add just alts of users and other ads type posts.)

# %%
alt_list = []

# %%
ig_bot = InstagramBot(username = '', password = '')
ig_bot.login()
for post in df_posts['post_link'][(df_posts['type'] == 'user') | (df_posts['type'] == 'other_ads')]:
    ig_bot.nav_post(post)
    alt_text = ig_bot.retrieve_alt()
    if alt_text.find('Image may contain:') != -1:
        alt_text = alt_text.split('.')[1]
        temp = (post, alt_text[alt_text.find(':') + 1 :].lstrip())
        alt_list.append(temp)
        print(f'alt text: {alt_text[alt_text.find(":") + 1 :].lstrip()} added to the key: {post}')
    else:
        print(f'{post} image does not have a alt tag.')
print(alt_list)
# Out:
# BhIjhiuF0Ip image does not have a alt tag.
# BgGYNWABqeh image does not have a alt tag.
# BgGYMmoBFjd image does not have a alt tag.
# BgGYLjjB2_Q image does not have a alt tag.
# BfqQTe9FHvR image does not have a alt tag.
# BfbUf-_lhXu image does not have a alt tag.
# alt text: phone added to the key: BeVQnOEFA-O
# alt text: indoor added to the key: Bd-qCY4lATh
# BdqDAuCl3ZP image does not have a alt tag.
# BdqC_7alK7b image does not have a alt tag.
# BdqC-_iFRXp image does not have a alt tag.
# Bc7tHnRFiN9 image does not have a alt tag.
# Bc7tETEFn9G image does not have a alt tag.
# alt text: shoes added to the key: Bc7s_UTlHbV
# Bcu4S-mFqp5 image does not have a alt tag.
# BbZs7GvF3J9 image does not have a alt tag.
# BbKeKPGlFS2 image does not have a alt tag.
# BbHzJXTFZKf image does not have a alt tag.
# alt text: 1 person added to the key: BZbltprFKEU
# alt text: 1 person added to the key: BZblsArllWq
# alt text: 2 people added to the key: BZblqcsFySj
# alt text: 1 person, closeup added to the key: BZbEyi-F9yA
# alt text: 2 people added to the key: BZbExQXlSyy
# alt text: 1 person added to the key: BZbEvrCls82
# alt text: 1 person added to the key: BZbCGHvl1I8
# alt text: one or more people and text added to the key: BZbCEA8FVKF
# alt text: 1 person added to the key: BZbCCcWFYM8
# alt text: 1 person added to the key: BZa-gWOF-7Z
# BZa-em0loxe image does not have a alt tag.
# alt text: 1 person, sitting, eyeglasses and closeup added to the key: BZa-c3TlY2L
# alt text: 2 people, sunglasses added to the key: BZa8gH6Fwmb
# alt text: 1 person added to the key: BZa8emTlX2Q
# alt text: 1 person added to the key: BZa8busFTwP
# alt text: 1 person, text and closeup added to the key: BZZCWPKlljP
# alt text: 1 person added to the key: BZZCVF_F82P
# alt text: 1 person added to the key: BZZCS7KFS3F
# alt text: 1 person added to the key: BZYoj9rF-lb
# alt text: 1 person added to the key: BZYoTSsF081
# alt text: 2 people added to the key: BZYoSdjFVWv
# alt text: 2 people, text added to the key: BZYmaGflQd-
# alt text: 1 person added to the key: BZYmYXilc-b
# alt text: 1 person added to the key: BZYmWK2lmyv
# alt text: 1 person added to the key: BZTt34rl7EG
# alt text: elmii added to the key: BZTtzhflTkr
# alt text: ir, and @mohsen added to the key: BZTtUC6FjIx
# alt text: 1 person added to the key: BZRM-RmlXo1
# alt text: 2 people added to the key: BZRMyTIlFhU
# alt text: 1 person, sleeping, baby and closeup added to the key: BZRMw9Pl33X
# alt text: 1 person added to the key: BZNuABylNqk
# alt text: one or more people and text added to the key: BZNt1D0l0Wz
# alt text: 1 person, sunglasses added to the key: BZNtH2NF_re
# alt text: 1 person added to the key: BZNtDBaFj0O
# alt text: 1 person added to the key: BZNtAwVF4kf
# alt text: 1 person added to the key: BZMGbSRl_4y
# BZMGZSrlOKE image does not have a alt tag.
# alt text: 1 person added to the key: BZMGX0Qlkxo
# alt text: 1 person added to the key: BZLbEu1FjZ2
# alt text: 1 person, closeup added to the key: BZLbCTvl3p4
# alt text: 2 people added to the key: BZLbBFZFWBu
# alt text: 2 people added to the key: BZG6GFYFx3R
# alt text: 1 person, closeup added to the key: BZG6D_JlR-z
# alt text: 2 people added to the key: BZG6CcplTQq
# alt text: one or more people and text added to the key: BZGdk1Dl5u0
# alt text: 1 person added to the key: BZGdjXmFy6E
# alt text: 1 person added to the key: BZGdhvGlYGt
# BZDnCTzlUCc image does not have a alt tag.
# alt text: 1 person added to the key: BZDm-6GFb9X
# alt text: 1 person added to the key: BZDm89dFJoy
# alt text: 2 people added to the key: BZBw3dtliz1
# alt text: 1 person added to the key: BZBw1a5lSQx
# alt text: 1 person added to the key: BZBwyvclWUY
# alt text: 1 person added to the key: BY_IwuUFfa_
# alt text: 2 people, people standing, tree, outdoor and nature added to the key: BY_IuVMleE6
# alt text: 1 person added to the key: BY_Ioqil0tF
# alt text: 1 person added to the key: BY-pxaAFBvJ
# alt text: 1 person added to the key: BY-pup8F9IM
# alt text: 1 person added to the key: BY-prqfF2HW
# alt text: 1 person added to the key: BY8L5i5lCdM
# alt text: 1 person added to the key: BY8Lsi0FvfJ
# alt text: 1 person added to the key: BY3Z-6-FMAX
# alt text: 1 person added to the key: BY3Z88hFHUO
# alt text: 1 person added to the key: BY3Z7WMFzWi
# alt text: 2 people added to the key: BY2zLpiF8dp
# alt text: 1 person added to the key: BY2zJbMFuQc
# alt text: 1 person added to the key: BY2zHD2Feyo
# alt text: 2 people added to the key: BY0EBdPF0tN
# alt text: 1 person, text added to the key: BY0D6arlvgW
# BYyQv5VljTP image does not have a alt tag.
# alt text: outdoor added to the key: BYyQttkliTp
# BYyQrxdFBac image does not have a alt tag.
# alt text: 2 people added to the key: BYvs4ZBFEh9
# alt text: 1 person added to the key: BYvs1pvljLD
# alt text: 1 person, text added to the key: BYvsy49Fs1H
# alt text: 9 people added to the key: BYvNETplU0f
# alt text: 1 person added to the key: BYvBvAJlq8f
# BYvBqdHF1Q_ image does not have a alt tag.
# alt text: 1 person added to the key: BYsWzcmlKP8
# alt text: 1 person, eyeglasses and closeup added to the key: BYsWsa6F7rN
# alt text: 1 person added to the key: BYsWnqeFD-J
# alt text: 1 person, outdoor added to the key: BYqkhFsFS-3
# BYqkfPFlsMJ image does not have a alt tag.
# alt text: 1 person added to the key: BYqkdVKlZkU
# alt text: 1 person added to the key: BYoOJ76lhum
# alt text: 2 people added to the key: BYoOIDwFEfV
# alt text: 3 people added to the key: BYoOFyoFqYd
# alt text: 1 person added to the key: BYnSh0UF6uN
# alt text: 1 person added to the key: BYnSeVtFZ5D
# alt text: 1 person added to the key: BYnSbnrFFTg
# BYkuje4FvJq image does not have a alt tag.
# alt text: 1 person, child added to the key: BYkugHulaBV
# alt text: 1 person added to the key: BYkuduylL36
# alt text: 1 person added to the key: BYi06-iFucp
# alt text: 1 person added to the key: BYi05RxFF89
# alt text: 1 person added to the key: BYi02lvl3Qn
# alt text: 1 person added to the key: BYgQJ3YF-VB
# alt text: 1 person added to the key: BYgQITdlLGm
# alt text: 1 person added to the key: BYgQFmqloOv
# alt text: 1 person, closeup added to the key: BYfgOT0FSA2
# alt text: 1 person added to the key: BYfgKstlYil
# alt text: 2 people, closeup added to the key: BYfgEzWlAZD
# alt text: 4 people added to the key: BYdtUBhlSnS
# alt text: 1 person added to the key: BYdtR-4lyAQ
# alt text: 1 person added to the key: BYdtOdFlWuO
# alt text: 1 person added to the key: BYc9_3vlYay
# alt text: 1 person, closeup added to the key: BYc95eiFJfH
# alt text: 1 person, sunglasses added to the key: BYaguJvFaMn
# alt text: 1 person added to the key: BYagq8hFGyG
# BYagn9rFymv image does not have a alt tag.
# alt text: 1 person added to the key: BYYiSYClYnh
# alt text: 1 person added to the key: BYYiPxSF3Uq
# alt text: 1 person added to the key: BYYiNZKFHTA
# BYX0u27FPI5 image does not have a alt tag.
# alt text: 1 person added to the key: BYX0mE-FQyc
# alt text: one or more people added to the key: BYX0kgQFx3H
# alt text: 1 person, standing and outdoor added to the key: BYV-ZwQlYT4
# alt text: 1 person added to the key: BYV-NRxFUY_
# alt text: 1 person added to the key: BYVXWj9FhJ0
# alt text: 1 person added to the key: BYVXPhrlc2s
# alt text: 2 people added to the key: BYTWmKKlTCO
# alt text: 1 person, closeup added to the key: BYTWfualxLZ
# alt text: 1 person added to the key: BYQ7UT1FYzu
# alt text: 1 person, sitting and closeup added to the key: BYQ7Qsal_zA
# alt text: 1 person added to the key: BYQ7NfClOKt
# alt text: 1 person, sunglasses and text added to the key: BYQKZy_FaWx
# alt text: 1 person added to the key: BYQKOQ1FaI0
# alt text: 1 person, text added to the key: BYNoiGTl0kv
# alt text: 1 person added to the key: BYNoY2ulFHw
# alt text: 1 person, closeup added to the key: BYLrJi4FRce
# alt text: 1 person added to the key: BYLqbmnFhsj
# alt text: 1 person, closeup added to the key: BYJFqnjliJw
# alt text: 1 person added to the key: BYJFcnwlUjV
# alt text: one or more people, people sleeping and closeup added to the key: BYIk54WlSaH
# BYIkzSmlMNm image does not have a alt tag.
# alt text: 2 people added to the key: BYF6-pllBGk
# alt text: 1 person added to the key: BYF62OOF4E4
# alt text: 1 person added to the key: BYD8708F-uS
# alt text: 1 person added to the key: BYD8xddlS-m
# alt text: 1 person added to the key: BYBYZVUFp2O
# alt text: 1 person, selfie and closeup added to the key: BYBYOFkF3jA
# alt text: 1 person, text added to the key: BYAofZnlUbH
# alt text: 2 people added to the key: BYAoZYcl_XA
# alt text: 1 person, outdoor added to the key: BYAoPfdlirU
# alt text: 1 person added to the key: BX-VtlHln9Q
# alt text: 1 person added to the key: BX-VP4vl3Sl
# alt text: 1 person added to the key: BX8J4KDlTYN
# alt text: one or more people added to the key: BX8J1dCFyrP
# alt text: 1 person, closeup and text added to the key: BX8JyFSF6UO
# [('BeVQnOEFA-O', 'phone'), ('Bd-qCY4lATh', 'indoor'), ('BeVQnOEFA-O', 'phone'), ('Bd-qCY4lATh', 'indoor'), ('Bc7s_UTlHbV', 'shoes'), ('BZbltprFKEU', '1 person'), ('BZblsArllWq', '1 person'), ('BZblqcsFySj', '2 people'), ('BZbEyi-F9yA', '1 person, closeup'), ('BZbExQXlSyy', '2 people'), ('BZbEvrCls82', '1 person'), ('BZbCGHvl1I8', '1 person'), ('BZbCEA8FVKF', 'one or more people and text'), ('BZbCCcWFYM8', '1 person'), ('BZa-gWOF-7Z', '1 person'), ('BZa-c3TlY2L', '1 person, sitting, eyeglasses and closeup'), ('BZa8gH6Fwmb', '2 people, sunglasses'), ('BZa8emTlX2Q', '1 person'), ('BZa8busFTwP', '1 person'), ('BZZCWPKlljP', '1 person, text and closeup'), ('BZZCVF_F82P', '1 person'), ('BZZCS7KFS3F', '1 person'), ('BZYoj9rF-lb', '1 person'), ('BZYoTSsF081', '1 person'), ('BZYoSdjFVWv', '2 people'), ('BZYmaGflQd-', '2 people, text'), ('BZYmYXilc-b', '1 person'), ('BZYmWK2lmyv', '1 person'), ('BZTt34rl7EG', '1 person'), ('BZTtzhflTkr', 'elmii'), ('BZTtUC6FjIx', 'ir, and @mohsen'), ('BZRM-RmlXo1', '1 person'), ('BZRMyTIlFhU', '2 people'), ('BZRMw9Pl33X', '1 person, sleeping, baby and closeup'), ('BZNuABylNqk', '1 person'), ('BZNt1D0l0Wz', 'one or more people and text'), ('BZNtH2NF_re', '1 person, sunglasses'), ('BZNtDBaFj0O', '1 person'), ('BZNtAwVF4kf', '1 person'), ('BZMGbSRl_4y', '1 person'), ('BZMGX0Qlkxo', '1 person'), ('BZLbEu1FjZ2', '1 person'), ('BZLbCTvl3p4', '1 person, closeup'), ('BZLbBFZFWBu', '2 people'), ('BZG6GFYFx3R', '2 people'), ('BZG6D_JlR-z', '1 person, closeup'), ('BZG6CcplTQq', '2 people'), ('BZGdk1Dl5u0', 'one or more people and text'), ('BZGdjXmFy6E', '1 person'), ('BZGdhvGlYGt', '1 person'), ('BZDm-6GFb9X', '1 person'), ('BZDm89dFJoy', '1 person'), ('BZBw3dtliz1', '2 people'), ('BZBw1a5lSQx', '1 person'), ('BZBwyvclWUY', '1 person'), ('BY_IwuUFfa_', '1 person'), ('BY_IuVMleE6', '2 people, people standing, tree, outdoor and nature'), ('BY_Ioqil0tF', '1 person'), ('BY-pxaAFBvJ', '1 person'), ('BY-pup8F9IM', '1 person'), ('BY-prqfF2HW', '1 person'), ('BY8L5i5lCdM', '1 person'), ('BY8Lsi0FvfJ', '1 person'), ('BY3Z-6-FMAX', '1 person'), ('BY3Z88hFHUO', '1 person'), ('BY3Z7WMFzWi', '1 person'), ('BY2zLpiF8dp', '2 people'), ('BY2zJbMFuQc', '1 person'), ('BY2zHD2Feyo', '1 person'), ('BY0EBdPF0tN', '2 people'), ('BY0D6arlvgW', '1 person, text'), ('BYyQttkliTp', 'outdoor'), ('BYvs4ZBFEh9', '2 people'), ('BYvs1pvljLD', '1 person'), ('BYvsy49Fs1H', '1 person, text'), ('BYvNETplU0f', '9 people'), ('BYvBvAJlq8f', '1 person'), ('BYsWzcmlKP8', '1 person'), ('BYsWsa6F7rN', '1 person, eyeglasses and closeup'), ('BYsWnqeFD-J', '1 person'), ('BYqkhFsFS-3', '1 person, outdoor'), ('BYqkdVKlZkU', '1 person'), ('BYoOJ76lhum', '1 person'), ('BYoOIDwFEfV', '2 people'), ('BYoOFyoFqYd', '3 people'), ('BYnSh0UF6uN', '1 person'), ('BYnSeVtFZ5D', '1 person'), ('BYnSbnrFFTg', '1 person'), ('BYkugHulaBV', '1 person, child'), ('BYkuduylL36', '1 person'), ('BYi06-iFucp', '1 person'), ('BYi05RxFF89', '1 person'), ('BYi02lvl3Qn', '1 person'), ('BYgQJ3YF-VB', '1 person'), ('BYgQITdlLGm', '1 person'), ('BYgQFmqloOv', '1 person'), ('BYfgOT0FSA2', '1 person, closeup'), ('BYfgKstlYil', '1 person'), ('BYfgEzWlAZD', '2 people, closeup'), ('BYdtUBhlSnS', '4 people'), ('BYdtR-4lyAQ', '1 person'), ('BYdtOdFlWuO', '1 person'), ('BYc9_3vlYay', '1 person'), ('BYc95eiFJfH', '1 person, closeup'), ('BYaguJvFaMn', '1 person, sunglasses'), ('BYagq8hFGyG', '1 person'), ('BYYiSYClYnh', '1 person'), ('BYYiPxSF3Uq', '1 person'), ('BYYiNZKFHTA', '1 person'), ('BYX0mE-FQyc', '1 person'), ('BYX0kgQFx3H', 'one or more people'), ('BYV-ZwQlYT4', '1 person, standing and outdoor'), ('BYV-NRxFUY_', '1 person'), ('BYVXWj9FhJ0', '1 person'), ('BYVXPhrlc2s', '1 person'), ('BYTWmKKlTCO', '2 people'), ('BYTWfualxLZ', '1 person, closeup'), ('BYQ7UT1FYzu', '1 person'), ('BYQ7Qsal_zA', '1 person, sitting and closeup'), ('BYQ7NfClOKt', '1 person'), ('BYQKZy_FaWx', '1 person, sunglasses and text'), ('BYQKOQ1FaI0', '1 person'), ('BYNoiGTl0kv', '1 person, text'), ('BYNoY2ulFHw', '1 person' ...

# %% [markdown]
# in the next cell we quickly save our progress to a dataframe.

# %%
temp_post_list = []
temp_alt_list = []
for item in alt_list:
    temp_post_list.append(item[0])
    temp_alt_list.append(item[1])

df_alt = pd.DataFrame(data = {'post_link' : temp_post_list,
                              'alt_text' : temp_alt_list})
df_alt.to_excel(excel_writer = "data/alt_user_otherads.xlsx")

# %% [markdown]
# with a quick check of the dictionary, we found out that there are some errors in that:
#
# - our algorithm couldn't detect alt attribute of images with tagged persons in it.
# - our algorithm didn't detect alt attribute of images which are multiple.
